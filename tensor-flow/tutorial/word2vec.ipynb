# %%
# https://www.tensorflow.org/versions/master/tutorials/word2vec/index.html
# %matplotlib inline
import tensorflow as tf
import numpy as np

from __future__ import absolute_import
from __future__ import print_function
import tensorflow.python.platform
import collections
import math
import os
import random
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import zipfile

# %%
# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'
dir = 'word2vec/'
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if  os.path.exists(dir + filename):
        return dir + filename

  if not os.path.exists(dir + filename):
    filename, _ = urllib.request.urlretrieve(url + filename, dir + filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

# %%
filename = maybe_download('text8.zip', 31344016)

# %%
# Read the data into a string.
def read_data(filename):
  f = zipfile.ZipFile(filename)
  for name in f.namelist():
    return f.read(name).split()
  f.close()

# %%
words = read_data(filename)
print('Data size', len(words))
# Out:
# Data size 17005207

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000
def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reverse_dictionary

# %%
data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
# Step 4: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], '->', labels[i, 0])
  print(reverse_dictionary[batch[i]], '->', reverse_dictionary[labels[i, 0]])
# Out:
# 3084 -> 12
# originated -> as
# 3084 -> 5239
# originated -> anarchism
# 12 -> 6
# as -> a
# 12 -> 3084
# as -> originated
# 6 -> 195
# a -> term
# 6 -> 12
# a -> as
# 195 -> 2
# term -> of
# 195 -> 6
# term -> a

# %%
# Step 5: Build and train a skip-gram model.
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(np.arange(valid_window), valid_size))
num_sampled = 64    # Number of negative examples to sample.
graph = tf.Graph()
with graph.as_default():
  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)
    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))
  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(nce_weights, nce_biases, embed, train_labels,
                     num_sampled, vocabulary_size))
  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)
  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

# %%
# Step 6: Begin training
num_steps = 100001
with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  tf.initialize_all_variables().run()
  print("Initialized")
  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}
    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print("Average loss at step ", step, ": ", average_loss)
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log_str = "Nearest to %s:" % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = "%s %s," % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  325.904327393
# Nearest to one: shuffling, mulatto, teil, conical, aviators, hird, engagements, augment,
# Nearest to to: siculus, glad, bwv, microinstruction, buoyant, communicative, nuova, oppressed,
# Nearest to is: arbitrators, blackjack, gmt, arian, masons, permutations, moshe, appreciably,
# Nearest to between: fellow, impressively, hormones, kicking, capacitance, physics, theodicy, roosevelt,
# Nearest to in: stipulate, kingfisher, feel, dks, fenian, easterly, maps, feasibility,
# Nearest to seven: investigate, bulls, ankle, eurocents, som, cristae, tractor, afford,
# Nearest to three: symmetric, malinowski, tales, gustavo, grampus, wavefunction, husbandry, milestone,
# Nearest to nine: fractal, petrie, oracles, formaldehyde, kohlberg, jessie, confirms, zelda,
# Nearest to some: arcadius, artwork, innovator, exhaustive, aac, scholar, ping, lingual,
# Nearest to there: cav, skinned, bayreuth, replace, angrily, transceiver, postmillennialism, underdog,
# Nearest to had: boitano, unobservable, thief, phenols, torah, barbarossa, neil, eaters,
# Nearest to are: citizens, impressions, sea, alnus, flip, consumers, hartmann, internecine,
# Nearest to but: server, bentine, ladakh, wife, brat, plaid, vulnerability, shamanic,
# Nearest to people: scrupulous, druid, subsidised, peggy, alcohol, robbers, stirling, convenes,
# Nearest to its: oligocene, chats, winchester, strand, strewn, cellists, egyptologist, clothed,
# Nearest to so: shorelines, yung, mancha, bethlehem, gimp, netscape, oscilloscope, qazaqstan,
# Average loss at step
#  2000 :  112.996631598
# Average loss at step
#  4000 :  53.132993495
# Average loss at step
#  6000 :  33.3437644355
# Average loss at step
#  8000 :  23.881936011
# Average loss at step
#  10000 :  17.9118791134
# Nearest to one: vs, austin, two, analogue, gland, victoriae, UNK, bang,
# Nearest to to: and, in, analogue, with, methadone, nine, of, ari,
# Nearest to is: was, are, has, create, in, and, marked, as,
# Nearest to between: physics, commit, jerusalem, kicking, fellow, gland, pal, quality,
# Nearest to in: and, on, of, from, austin, for, to, with,
# Nearest to seven: vs, austin, nine, reginae, zero, implicit, tissue, bang,
# Nearest to three: zero, vs, nine, malinowski, one, gland, austin, agave,
# Nearest to nine: austin, zero, vs, gland, reginae, implicit, analogue, six,
# Nearest to some: artwork, the, lasted, ping, proceed, vs, homomorphism, mathbf,
# Nearest to there: vs, devil, virtue, occupation, astounding, bull, orange, element,
# Nearest to had: torah, identification, have, would, dover, mall, austin, quoting,
# Nearest to are: is, vs, and, deke, were, eeeeee, exodus, carrel,
# Nearest to but: server, victoriae, wife, and, believers, exist, austin, in,
# Nearest to people: scrupulous, basins, bull, bullet, seward, alcohol, hitchcock, germany,
# Nearest to its: the, oligocene, traditional, vs, hearing, millions, gland, vehicle,
# Nearest to so: cl, vs, victoriae, wish, apocalypse, saints, austin, components,
# Average loss at step
#  12000 :  13.8489292265
# Average loss at step
#  14000 :  11.8973853465
# Average loss at step
#  16000 :  9.8588450067
# Average loss at step
#  18000 :  8.49023900807
# Average loss at step
#  20000 :  7.84775868928
# Nearest to one: two, dasyprocta, agouti, three, eight, vs, four, gland,
# Nearest to to: in, and, nine, for, analogue, by, with, annales,
# Nearest to is: was, are, has, were, as, dasyprocta, nine, msg,
# Nearest to between: in, commit, physics, of, pal, jerusalem, gland, with,
# Nearest to in: and, on, of, at, for, dasyprocta, from, by,
# Nearest to seven: nine, zero, eight, four, six, five, dasyprocta, three,
# Nearest to three: zero, two, four, nine, eight, five, dasyprocta, seven,
# Nearest to nine: eight, six, seven, zero, dasyprocta, five, four, agouti,
# Nearest to some: the, artwork, lasted, all, arcadius, its, proceed, any,
# Nearest to there: vs, dye, devil, bayreuth, astounding, marischal, virtue, skits,
# Nearest to had: have, was, has, would, dover, msg, is, identification,
# Nearest to are: is, were, was, zero, been, and, vs, deke,
# Nearest to but: and, is, victoriae, server, that, msg, could, dasyprocta,
# Nearest to people: scrupulous, seward, dasyprocta, bull, alpina, agouti, peggy, hitchcock,
# Nearest to its: the, his, some, oligocene, their, vs, traditional, winchester,
# Nearest to so: agouti, vs, annex, guts, victoriae, eluded, cl, senators,
# Average loss at step
#  22000 :  7.35963427234
# Average loss at step
#  24000 :  6.92580001247
# Average loss at step
#  26000 :  6.71675632632
# Average loss at step
#  28000 :  6.09010971439
# Average loss at step
#  30000 :  6.14889788771
# Nearest to one: two, three, four, five, aba, six, seven, eight,
# Nearest to to: in, analogue, for, and, nine, akita, would, six,
# Nearest to is: was, are, has, were, as, akita, dasyprocta, for,
# Nearest to between: of, with, in, commit, hormones, physics, pal, ari,
# Nearest to in: and, on, at, from, of, with, for, by,
# Nearest to seven: eight, nine, six, four, five, three, zero, dasyprocta,
# Nearest to three: four, five, eight, six, seven, nine, two, dasyprocta,
# Nearest to nine: eight, six, seven, five, four, zero, three, dasyprocta,
# Nearest to some: many, the, all, any, artwork, lasted, their, arcadius,
# Nearest to there: they, it, vs, dye, also, astounding, now, not,
# Nearest to had: have, has, was, is, would, having, by, dover,
# Nearest to are: were, is, akita, was, be, been, trinomial, vs,
# Nearest to but: and, victoriae, could, will, msg, that, is, dasyprocta,
# Nearest to people: agp, scrupulous, seward, druid, peggy, alpina, dasyprocta, guinness,
# Nearest to its: the, their, his, reuptake, caterpillars, winchester, some, oligocene,
# Nearest to so: eluded, senators, agouti, abitibi, vs, chalukyas, sandstone, annex,
# Average loss at step
#  32000 :  5.81844093907
# Average loss at step
#  34000 :  5.82379131842
# Average loss at step
#  36000 :  5.66893573463
# Average loss at step
#  38000 :  5.30694716239
# Average loss at step
#  40000 :  5.45913186932
# Nearest to one: two, six, seven, five, dasyprocta, four, eight, three,
# Nearest to to: analogue, nine, akita, dasyprocta, for, annales, six, with,
# Nearest to is: was, are, has, were, dasyprocta, became, akita, msg,
# Nearest to between: with, in, lemmy, commit, from, hormones, during, of,
# Nearest to in: and, at, on, from, dasyprocta, msg, with, of,
# Nearest to seven: eight, six, five, four, nine, three, zero, dasyprocta,
# Nearest to three: four, five, two, six, seven, eight, zero, dasyprocta,
# Nearest to nine: eight, seven, six, zero, four, five, dasyprocta, three,
# Nearest to some: many, all, the, any, these, their, artwork, righteousness,
# Nearest to there: it, they, vs, now, he, dye, also, strikeouts,
# Nearest to had: has, have, was, were, having, would, is, been,
# Nearest to are: were, is, was, be, have, and, akita, although,
# Nearest to but: and, that, victoriae, where, dasyprocta, agouti, six, which,
# Nearest to people: spoon, agp, druid, scrupulous, seward, citizen, alpina, guinness,
# Nearest to its: their, the, his, reuptake, winchester, caterpillars, some, vs,
# Nearest to so: agouti, senators, however, abitibi, eluded, sandstone, annex, guts,
# Average loss at step
#  42000 :  5.33177966297
# Average loss at step
#  44000 :  5.34169745088
# Average loss at step
#  46000 :  5.26301707876
# Average loss at step
#  48000 :  5.01248820925
# Average loss at step
#  50000 :  5.16267684972
# Nearest to one: two, six, four, eight, three, dasyprocta, five, seven,
# Nearest to to: analogue, would, akita, nine, can, tonic, for, dasyprocta,
# Nearest to is: was, are, has, were, although, became, eight, naaman,
# Nearest to between: with, commit, in, lemmy, hormones, during, two, from,
# Nearest to in: at, and, from, on, of, for, dasyprocta, with,
# Nearest to seven: eight, six, four, five, nine, three, zero, dasyprocta,
# Nearest to three: four, five, six, two, seven, eight, one, dasyprocta,
# Nearest to nine: eight, six, seven, zero, five, four, dasyprocta, three,
# Nearest to some: many, these, all, the, their, any, lasted, both,
# Nearest to there: it, they, vs, now, he, skits, not, also,
# Nearest to had: has, have, was, were, sotho, having, been, cowan,
# Nearest to are: were, is, have, was, be, akita, eight, although,
# Nearest to but: and, thibetanus, dasyprocta, agouti, victoriae, six, akita, austin,
# Nearest to people: spoon, agp, scrupulous, seward, druid, citizen, peggy, alpina,
# Nearest to its: their, his, the, reuptake, winchester, caterpillars, some, strand,
# Nearest to so: however, senators, sandstone, abitibi, agouti, guts, testes, dasyprocta,
# Average loss at step
#  52000 :  5.17204317427
# Average loss at step
#  54000 :  5.12307059681
# Average loss at step
#  56000 :  5.05132018435
# Average loss at step
#  58000 :  5.11698824465
# Average loss at step
#  60000 :  4.95623270774
# Nearest to one: two, six, four, five, three, eight, seven, dasyprocta,
# Nearest to to: would, analogue, nine, for, akita, tonic, can, dasyprocta,
# Nearest to is: was, are, has, although, callithrix, tamarin, dasyprocta, michelob,
# Nearest to between: with, in, commit, during, of, lemmy, among, hormones,
# Nearest to in: at, on, tamarin, and, of, callithrix, dasyprocta, msg,
# Nearest to seven: eight, six, five, nine, four, three, zero, ssbn,
# Nearest to three: five, four, six, seven, eight, two, zero, nine,
# Nearest to nine: eight, six, seven, five, four, zero, three, callithrix,
# Nearest to some: many, these, all, any, several, their, the, callithrix,
# Nearest to there: it, they, now, he, callithrix, vs, microcebus, which,
# Nearest to had: has, have, was, were, sotho, having, been, by,
# Nearest to are: were, is, have, be, akita, was, paraguay, callithrix,
# Nearest to but: and, michelob, however, tamarin, callithrix, which, thibetanus, wct,
# Nearest to people: spoon, agp, druid, microcebus, seward, scrupulous, citizen, guinness,
# Nearest to its: their, his, the, callithrix, reuptake, tamarin, winchester, some,
# Nearest to so: however, balochistan, agouti, senators, testes, abitibi, sandstone, dasyprocta,
# Average loss at step
#  62000 :  4.79671744072
# Average loss at step
#  64000 :  4.80039167285
# Average loss at step
#  66000 :  4.97327930033
# Average loss at step
#  68000 :  4.90546346557
# Average loss at step
#  70000 :  4.77196065772
# Nearest to one: two, six, four, five, three, eight, seven, dasyprocta,
# Nearest to to: analogue, would, akita, for, can, nine, tonic, thaler,
# Nearest to is: was, are, has, became, although, naaman, callithrix, dasyprocta,
# Nearest to between: with, during, commit, in, from, among, hormones, lemmy,
# Nearest to in: at, on, msg, tamarin, dasyprocta, callithrix, and, wct,
# Nearest to seven: six, eight, five, four, nine, three, zero, ssbn,
# Nearest to three: four, five, six, seven, two, eight, one, dasyprocta,
# Nearest to nine: eight, seven, six, five, four, zero, three, dasyprocta,
# Nearest to some: many, these, all, several, the, any, their, both,
# Nearest to there: they, it, now, callithrix, he, vs, microcebus, skits,
# Nearest to had: has, have, was, were, having, sotho, been, by,
# Nearest to are: were, is, have, be, although, was, akita, clo,
# Nearest to but: and, michelob, however, which, tamarin, thibetanus, callithrix, wct,
# Nearest to people: spoon, agp, druid, scrupulous, citizen, guinness, seward, microcebus,
# Nearest to its: their, his, the, callithrix, some, reuptake, tamarin, winchester,
# Nearest to so: however, thaler, clo, agouti, balochistan, rearranged, testes, dasyprocta,
# Average loss at step
#  72000 :  4.79461918962
# Average loss at step
#  74000 :  4.78926153839
# Average loss at step
#  76000 :  4.85950895381
# Average loss at step
#  78000 :  4.79502513361
# Average loss at step
#  80000 :  4.80789149642
# Nearest to one: six, two, seven, four, three, callithrix, five, dasyprocta,
# Nearest to to: would, analogue, will, akita, nine, for, tonic, can,
# Nearest to is: was, has, are, became, although, naaman, be, callithrix,
# Nearest to between: with, during, in, commit, among, from, waterfalls, lemmy,
# Nearest to in: at, on, from, tamarin, during, and, msg, nine,
# Nearest to seven: six, eight, five, four, nine, three, zero, ssbn,
# Nearest to three: four, five, six, two, seven, eight, dasyprocta, zero,
# Nearest to nine: eight, seven, six, five, four, zero, three, dasyprocta,
# Nearest to some: many, these, all, several, both, any, the, most,
# Nearest to there: they, it, now, he, callithrix, vs, microcebus, still,
# Nearest to had: has, have, was, were, having, sotho, been, by,
# Nearest to are: were, is, have, be, although, include, eight, was,
# Nearest to but: and, however, michelob, tamarin, wct, thibetanus, which, callithrix,
# Nearest to people: spoon, agp, citizen, druid, guinness, seward, falsetto, alpina,
# Nearest to its: their, his, the, callithrix, her, reuptake, thaler, winchester,
# Nearest to so: clodius, thaler, however, techs, clo, agouti, dasyprocta, balochistan,
# Average loss at step
#  82000 :  4.80876113474
# Average loss at step
#  84000 :  4.78174056292
# Average loss at step
#  86000 :  4.74392919624
# Average loss at step
#  88000 :  4.6930093962
# Average loss at step
#  90000 :  4.74592458522
# Nearest to one: six, seven, four, two, eight, five, three, crb,
# Nearest to to: would, analogue, nine, akita, dasyprocta, can, will, thaler,
# Nearest to is: was, has, are, although, naaman, became, callithrix, dasyprocta,
# Nearest to between: with, during, among, commit, in, waterfalls, from, hormones,
# Nearest to in: at, during, and, dasyprocta, of, tamarin, under, delphinus,
# Nearest to seven: eight, five, six, four, nine, three, zero, ssbn,
# Nearest to three: four, five, two, six, seven, eight, dasyprocta, callithrix,
# Nearest to nine: eight, seven, six, five, zero, four, callithrix, dasyprocta,
# Nearest to some: many, these, several, all, both, any, most, their,
# Nearest to there: they, it, now, he, callithrix, which, still, microcebus,
# Nearest to had: has, have, was, were, having, sotho, been, by,
# Nearest to are: were, is, have, be, although, include, do, akita,
# Nearest to but: and, however, michelob, which, tamarin, wct, or, thibetanus,
# Nearest to people: spoon, citizen, agp, seward, druid, falsetto, guinness, alpina,
# Nearest to its: their, his, the, tamias, her, some, callithrix, damping,
# Nearest to so: clodius, however, techs, thaler, clo, rearranged, chapterhouse, is,
# Average loss at step
#  92000 :  4.70705441833
# Average loss at step
#  94000 :  4.62477170157
# Average loss at step
#  96000 :  4.73417455864
# Average loss at step
#  98000 :  4.61227765751
# Average loss at step
#  100000 :  4.68538313782
# Nearest to one: six, two, four, seven, five, callithrix, three, michelob,
# Nearest to to: analogue, would, will, nine, akita, dasyprocta, can, callithrix,
# Nearest to is: was, has, are, although, became, naaman, dasyprocta, callithrix,
# Nearest to between: with, during, among, in, commit, from, waterfalls, hormones,
# Nearest to in: at, during, tamarin, on, within, callithrix, dasyprocta, from,
# Nearest to seven: six, eight, five, four, nine, three, zero, ssbn,
# Nearest to three: four, five, six, two, seven, eight, dasyprocta, nine,
# Nearest to nine: eight, seven, six, five, four, zero, three, dasyprocta,
# Nearest to some: many, these, several, all, any, both, their, most,
# Nearest to there: they, it, he, now, callithrix, which, still, microcebus,
# Nearest to had: has, have, was, were, having, sotho, been, baccalaureate,
# Nearest to are: were, have, is, be, include, although, akita, those,
# Nearest to but: and, however, michelob, callithrix, tamarin, wct, which, thibetanus,
# Nearest to people: spoon, citizen, microcebus, seward, alpina, zero, agp, xhosa,
# Nearest to its: their, his, the, tamias, her, some, callithrix, reuptake,
# Nearest to so: however, clodius, thaler, techs, rearranged, elements, ronin, clo,

# %%
# Step 7: Visualize the embeddings.
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  #in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i,:]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')
  plt.savefig(filename)

# %%
try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt
  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels)
except ImportError:
  print("Please install sklearn and matplotlib to visualize embeddings.")
# Out:
# /Users/ta-murata/.pythonbrew/pythons/Python-2.7.2/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
final_embeddings.aa
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-701c807a620f> in <module>()
# ----> 1 final_embeddings.aa
#
# AttributeError: 'numpy.ndarray' object has no attribute 'aa'
